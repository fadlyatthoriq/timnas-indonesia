# %%
import pandas as pd

# Membaca file CSV
data = pd.read_csv('tweets.csv')
teks = data['tweet']  # Ganti 'kolom_teks' dengan nama kolom yang sesuai

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

nltk.download('stopwords')
stop_words = set(stopwords.words('indonesian'))

def preprocessing(teks):
    teks = re.sub(r'\W', ' ', teks)  # Menghapus karakter non-kata
    teks = teks.lower()  # Mengubah ke huruf kecil
    teks = word_tokenize(teks)  # Tokenisasi
    teks = [word for word in teks if word not in stop_words]  # Menghapus stopwords
    return ' '.join(teks)

cleaned_texts = teks.apply(preprocessing)

# %%
from gensim import corpora
from gensim.models import LdaModel

# Membuat dictionary dan corpus
dictionary = corpora.Dictionary(cleaned_texts.str.split())
corpus = [dictionary.doc2bow(text.split()) for text in cleaned_texts]

# Menerapkan LDA
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# %%
for idx, topic in lda_model.print_topics(-1):
    print(f'Topik {idx}: {topic}')

# %%
topic_distribution = [lda_model.get_document_topics(bow) for bow in corpus]
# Analisis lebih lanjut untuk menemukan topik yang paling banyak dibahas

# %%
from collections import Counter

# Menghitung frekuensi kemunculan setiap topik
topic_counts = Counter()
for doc_topics in topic_distribution:
    for topic, _ in doc_topics:
        topic_counts[topic] += 1

# Menampilkan 5 topik teratas
top_5_topics = topic_counts.most_common(5)
print("5 Topik Paling Banyak Dibahas:")
for topic, count in top_5_topics:
    print(f'Topik {topic}: {count} dokumen')

# Menampilkan kata kunci untuk setiap topik
print("\nKata Kunci untuk Setiap Topik:")
for idx in range(5):  # Hanya untuk 5 topik teratas
    print(f'Topik {idx}: {lda_model.print_topics(num_words=3)[idx][1]}')

# Menampilkan dokumen yang paling relevan untuk setiap topik teratas
print("\nDokumen Relevan untuk Topik Teratas:")
for topic, _ in top_5_topics:
    print(f'\nDokumen untuk Topik {topic}:')
    relevant_docs = [teks[i] for i, doc_topics in enumerate(topic_distribution) if any(t == topic for t, _ in doc_topics)]
    for doc in relevant_docs[:2]:  # Menampilkan 3 dokumen relevan
        print(f'- {doc}')
# Out:
# 5 Topik Paling Banyak Dibahas:
# Topik 1: 83 dokumen
# Topik 0: 81 dokumen
# Topik 2: 78 dokumen
# Topik 3: 78 dokumen
# Topik 4: 75 dokumen
#
# Kata Kunci untuk Setiap Topik:
# Topik 0: 0.047*"timnas" + 0.031*"rt" + 0.023*"idextratime"
# Topik 1: 0.041*"timnas" + 0.037*"https" + 0.035*"co"
# Topik 2: 0.029*"u" + 0.024*"indonesia" + 0.022*"20"
# Topik 3: 0.025*"timnas" + 0.023*"cb" + 0.023*"meshaal"
# Topik 4: 0.050*"timnas" + 0.029*"rt" + 0.026*"indonesia"
#
# Dokumen Relevan untuk Topik Teratas:
#
# Dokumen untuk Topik 1:
# - RT @idextratime: 🚨 BREAKING: Mathew Baker (LB/15/🇮🇩) mengumumkan lewat Story akun Instagramnya bahwa ia tidak akan lanjut di timnas Indones…
# - RT @idextratime: Abis ke minimarket beli minuman, terus nemu ini guys,  Indomilk Steril dengan gambar pemain Timnas dan ada coach Shin Tae-…
#
# Dokumen untuk Topik 0:
# - RT @idextratime: 🚨 BREAKING: Mathew Baker (LB/15/🇮🇩) mengumumkan lewat Story akun Instagramnya bahwa ia tidak akan lanjut di timnas Indones…
# - RT @idextratime: Abis ke minimarket beli minuman, terus nemu ini guys,  Indomilk Steril dengan gambar pemain Timnas dan ada coach Shin Tae-…
#
# Dokumen untuk Topik 2:
# - RT @idextratime: 🚨 BREAKING: Mathew Baker (LB/15/🇮🇩) mengumumkan lewat Story akun Instagramnya bahwa ia tidak akan lanjut di timnas Indones…
# - RT @idextratime: Abis ke minimarket beli minuman, terus nemu ini guys,  Indomilk Steril dengan gambar pemain Timnas dan ada coach Shin Tae-…
#
# Dokumen untuk Topik 3:
# - RT @idextratime: 🚨 BREAKING: Mathew Baker (LB/15/🇮🇩) mengumumkan lewat Story akun Instagramnya bahwa ia tidak akan lanjut di timnas Indones…
# - RT @idextratime: Abis ke minimarket beli minuman, terus nemu ini guys,  Indomilk Steril dengan gambar pemain Timnas dan ada coach Shin Tae-…
#
# Dokumen untuk Topik 4:
# - RT @idextratime: 🚨 BREAKING: Mathew Baker (LB/15/🇮🇩) mengumumkan lewat Story akun Instagramnya bahwa ia tidak akan lanjut di timnas Indones…
# - RT @idextratime: Abis ke minimarket beli minuman, terus nemu ini guys,  Indomilk Steril dengan gambar pemain Timnas dan ada coach Shin Tae-…

# %%
import pyLDAvis.gensim_models
import pyLDAvis

# Visualisasi model LDA
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1909616122674132003276797512" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1909616122674132003276797512_data = {"mdsDat": {"x": [-0.16120745742727016, 0.11435992647304799, 0.02453215937931832, 0.016084880982189066, 0.006230490592714468], "y": [0.06146500284020809, 0.11012399950630404, -0.012412833181580435, -0.14094189253823183, -0.01823427662669983], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [28.719165649063903, 25.095901269705724, 21.362537329944427, 17.215889043330794, 7.6065067079551465]}, "tinfo": {"Term": ["u", "meshaal", "cb", "20", "indonesia", "idextratime", "https", "pelatih", "2", "co", "t", "morisaki", "ctsubasa_indo", "gwijangge", "iqbal", "masuk", "menunda", "kedalam", "yuzo", "worl", "kuliahnya", "turnamen", "sma", "skuad", "jepang", "lulus", "update", "nakhonpathom", "santer", "allah", "minimarket", "gambar", "minuman", "indomilk", "nemu", "beli", "abis", "steril", "breaking", "mathew", "indones", "instagramnya", "mengumumkan", "akun", "lb", "15", "story", "laga", "guys", "baker", "away", "momen", "mengguyur", "jelang", "sesi", "seleksi", "latihan", "bandung", "cintada16", "indon", "idextratime", "rt", "timnas", "coach", "melawan", "yg", "tae", "pemain", "shin", "co", "t", "https", "morisaki", "ctsubasa_indo", "menunda", "kedalam", "yuzo", "kuliahnya", "worl", "turnamen", "skuad", "sma", "jepang", "lulus", "era", "timnasindonesia", "pemecatan", "kluivert", "berproses", "ngin", "mengaku", "anyar", "kehadiran", "haye", "tom", "proyek", "detikcom", "kandidat", "van", "fitriansyah", "seniman_bola", "bronckhorst", "masuk", "patrick", "sty", "nama", "indonesia", "timnas", "rt", "pemain", "pelatih", "amp", "shin", "yong", "tim", "yg", "t", "co", "https", "pribadi", "prancis", "halid", "nurdin", "nyinyirin", "wanti", "usik", "lapangan", "menit", "david", "menggantikan", "curacao", "bojan", "kastaneer", "52", "gervane", "silva", "hodak", "cedera", "menyatu", "da", "darah", "ekokuchiki", "dsana", "lahir", "merka", "iqballon14", "disana", "orang2", "psis_semarangg", "gak", "pssi", "https", "co", "t", "dipecat", "kursi", "yong", "senior", "target", "pelatih", "timnas", "kalo", "shin", "rt", "tae", "indonesia", "pemain", "tim", "coach", "asia", "aja", "sty", "nya", "lu", "gk", "menilai", "udah", "meshaal", "gwijangge", "iqbal", "update", "nakhonpathom", "santer", "allah", "insha", "cb", "idn_abroad", "ba", "bikin", "selamat", "2", "futsal", "hamzah", "ciwi", "18", "league", "lawannya", "thai", "16", "dituntaskan", "breakingskor", "b", "misi", "grup", "besok", "juara", "1", "nya", "umur", "amp", "putri", "u", "timnas", "kalo", "ya", "pemain", "udah", "t", "co", "https", "rt", "matthew", "80", "4xl", "bahela", "kitu", "bicara", "ajang", "indra", "sjafri", "tc", "tinggalkan", "baca", "penjelasan", "indr", "jebreeetmedia", "training", "psms", "60", "58", "400k", "3xl", "78", "wsa_medan", "64", "bnib", "bismillah", "persis", "300k", "225k", "bfc", "20", "u", "17", "selengkapnya", "piala", "bergabung", "indonesia", "pelatih", "target", "2025", "asia", "timnas", "rt", "baker", "2xl", "jersey4sale"], "Freq": [11.0, 7.0, 8.0, 7.0, 22.0, 14.0, 25.0, 10.0, 6.0, 25.0, 25.0, 6.0, 6.0, 4.0, 4.0, 10.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 4.0, 4.0, 5.476466950844612, 5.4764609181021955, 5.47636439422353, 5.4763026746280365, 5.476265550059319, 5.476227961433492, 5.476175522980178, 5.476105914413832, 4.714610473333437, 4.714494923113303, 4.71430233941308, 4.7142819209002855, 4.714238763589151, 4.714200710906216, 4.714123677426127, 4.713996061721159, 4.713902786242256, 3.193026380298492, 6.239127639325634, 5.294993705924579, 2.4342180619075937, 2.4328669596348242, 2.4328307631803243, 2.4328226421809176, 2.432804775982222, 2.4327887660119627, 2.4327667232992867, 2.432633074851903, 2.432577387998826, 2.432566250628211, 11.569285272682501, 15.366277571764385, 23.540778122852462, 5.478550567263892, 3.1933639818452684, 4.714890763827255, 5.47731571129692, 6.996322663177194, 5.476588997864272, 5.425403962801864, 5.408745240704019, 5.427565076758343, 6.0461078076624 ...

# %%
for idx, topic in lda_model.print_topics(num_words=10):
    print(f'Topik {idx}: {topic}')
# Out:
# Topik 0: 0.047*"timnas" + 0.031*"rt" + 0.023*"idextratime" + 0.014*"pemain" + 0.013*"guys" + 0.011*"coach" + 0.011*"tae" + 0.011*"shin" + 0.011*"minimarket" + 0.011*"gambar"
# Topik 1: 0.041*"timnas" + 0.037*"https" + 0.035*"co" + 0.035*"t" + 0.013*"rt" + 0.011*"pelatih" + 0.010*"gak" + 0.010*"shin" + 0.009*"indonesia" + 0.008*"pemain"
# Topik 2: 0.029*"u" + 0.024*"indonesia" + 0.022*"20" + 0.020*"timnas" + 0.013*"pelatih" + 0.011*"matthew" + 0.010*"rt" + 0.008*"piala" + 0.008*"80" + 0.008*"4xl"
# Topik 3: 0.025*"timnas" + 0.023*"cb" + 0.023*"meshaal" + 0.016*"2" + 0.014*"nya" + 0.014*"gwijangge" + 0.014*"iqbal" + 0.012*"https" + 0.012*"co" + 0.012*"u"
# Topik 4: 0.050*"timnas" + 0.029*"rt" + 0.026*"indonesia" + 0.017*"masuk" + 0.016*"pemain" + 0.014*"morisaki" + 0.014*"ctsubasa_indo" + 0.012*"kluivert" + 0.012*"menunda" + 0.012*"yuzo"
